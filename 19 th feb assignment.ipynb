# %%
# Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %%
# Ans = Flask is a web framework, it's a Python module that lets you develop web applications easily.
# Advantages = flask is lighweigh and flexible , easy  to learn , build in development server

# %%
# Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in
# Jupyter Notebook.

# %%
# Ans

# %% [markdown]
# ![image.png](attachment:a9414224-b022-4021-9eee-3f1a50633b8a.png)

# %%
# Q3. What is App routing in Flask? Why do we use app routes?

# %%
# App routing in Flask refers to the process of defining URL routes or endpoints that map to 
# specific functions in a Flask application. In Flask, we use the @app.route# () decorator to define these routes.

# %%
# Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
# route to show the following details:
# Company Name: ABC Corporation
# Location: India
# Contact Detail: 999-999-9999

# %%
# Ans

# %% [markdown]
# ![image.png](attachment:108d7246-787e-41fd-9d7f-c5bd0bdf2c55.png)

# %% [markdown]
# ![image.png](attachment:43d7ff36-545a-4599-bec7-0c445627d86e.png)

# %%
# Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the
# url_for() function.
